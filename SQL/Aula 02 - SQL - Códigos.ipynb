# %% [markdown]
# # Aula 2: SQL

# %% [markdown]
# ## Introdução

# %% [markdown]
# Nesta aula veremos as principais queries de consulta em sql

# %% [markdown]
# ## Conexao no db4free via sqlalchemy

# %%
# !pip install SQLAlchemy --user --upgrade

# %%
import yaml 
import sqlalchemy
import pandas as pd

# %%
with open('credentials.yml', 'r') as file:
    c = yaml.load(file, Loader=yaml.FullLoader)

# %% [markdown]
# - A engine deve estar no formato:
# - mysql://`user`:`password`@`host`:`port`/`database`

# %%
print('hello')
print("hello")
# Out:
# hello
# hello

# %%
sqlalchemy.__version__
# Out:
# '1.3.13'

# %%
engine = sqlalchemy.create_engine\
(f"mysql://{c['user']}:{c['password']}@{c['host']}:{c['port']}/{c['database']}")

# %% [markdown]
# ### UPLOAD TABLE

# %%
df = pd.read_csv('AtrasoCartaoCredito.csv')

# %%
df.head(2)
# Out:
#    ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  ValorCompraAnual  \
# 0   1       0               3   homem     22           1            7250.0
# 1   2       1               1  mulher     38           1           71283.0
#
#       GastoMax   GastoMedio  UF      CidadeResidencia     RegiaodoPais  \
# 0   517.857143   604.166667  MG  Morada Nova de Minas   Região Sudeste
# 1  5091.642857  5940.250000  RN      Marcelino Vieira  Região Nordeste
#
#    NumeroComprasOnline
# 0            54.924242
# 1           312.644737

# %%
import mysql.connector

#Conectando
con = mysql.connector.connect(user=credentials['user'], 
                              password=credentials['password'],
                              host=credentials['host'],
                              database=credentials['database'],
                              port=credentials['port'])

cursor = con.cursor()

# %%
query = 'SHOW TABLES'
cursor.execute(query)
cursor.fetchall()
# Out:
# [(bytearray(b'AtrasoCartaoCredito'),),
#  (bytearray(b'AtrasoCartaoCredito2'),),
#  (bytearray(b'Customers'),),
#  (bytearray(b'Customers2'),),
#  (bytearray(b'df_a'),),
#  (bytearray(b'df_b'),),
#  (bytearray(b'empresas'),),
#  (bytearray(b'empresas2'),)]

# %%
df.to_sql('AtrasoCartaoCredito2', engine)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  ValorCompraAnual  \
# 0   1       0               3   homem     22           1            7250.0
# 1   2       1               1  mulher     38           1           71283.0
# 2   3       1               3  mulher     26           0            7925.0
# 3   4       1               1  mulher     35           1             531.0
# 4   5       0               3   homem     35           0             805.0
#
#       GastoMax   GastoMedio  UF      CidadeResidencia     RegiaodoPais  \
# 0   517.857143   604.166667  MG  Morada Nova de Minas   Região Sudeste
# 1  5091.642857  5940.250000  RN      Marcelino Vieira  Região Nordeste
# 2   566.071429   660.416667  PR         Agudos do Sul       Região Sul
# 3    37.928571    44.250000  PR          Congonhinhas       Região Sul
# 4    57.500000    67.083333  BA               Morpará  Região Nordeste
#
#    NumeroComprasOnline
# 0            54.924242
# 1           312.644737
# 2            50.801282
# 3             2.528571
# 4             3.833333

# %% [markdown]
# ### SELECT e FROM

# %% [markdown]
# - Já vimos o `SELECT` e `FROM` na última aula
#     - `SELECT` seleciona as colunas que queremos trazer
#         - `*` seleciona toda das colunas
#     - `FROM` seleciona a tabela que analisaremos
# - Para facilitar a consulta, podemos aplicar o `LIMIT`, que define o número de linhas que a query irá trazer

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
'''

pd.read_sql(query, engine)
# Out:
#      index   ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0        0    1       0               3   homem     22           1
# 1        1    2       1               1  mulher     38           1
# 2        2    3       1               3  mulher     26           0
# 3        3    4       1               1  mulher     35           1
# 4        4    5       0               3   homem     35           0
# ..     ...  ...     ...             ...     ...    ...         ...
# 886    886  887       0               2   homem     27           0
# 887    887  888       1               1  mulher     19           0
# 888    888  889       0               3  mulher     35           1
# 889    889  890       1               1   homem     26           0
# 890    890  891       0               3   homem     32           0
#
#      ValorCompraAnual     GastoMax   GastoMedio  UF  \
# 0              7250.0   517.857143   604.166667  MG
# 1             71283.0  5091.642857  5940.250000  RN
# 2              7925.0   566.071429   660.416667  PR
# 3               531.0    37.928571    44.250000  PR
# 4               805.0    57.500000    67.083333  BA
# ..                ...          ...          ...  ..
# 886              13.0     0.928571     1.083333  BA
# 887              30.0     2.142857     2.500000  BA
# 888            2345.0   167.500000   195.416667  RO
# 889              30.0     2.142857     2.500000  PI
# 890             775.0    55.357143    64.583333  MA
#
#               CidadeResidencia     RegiaodoPais  NumeroComprasOnline
# 0         Morada Nova de Minas   Região Sudeste            54.924242
# 1             Marcelino Vieira  Região Nordeste           312.644737
# 2                Agudos do Sul       Região Sul            50.801282
# 3                 Congonhinhas       Região Sul             2.528571
# 4                      Morpará  Região Nordeste             3.833333
# ..                         ...              ...                  ...
# 886          Marcionílio Souza  Região Nordeste             0.080247
# 887                    Mirante  Região Nordeste             0.263158
# 888  Governador Jorge Teixeira     Região Norte            11.166667
# 889    Baixa Grande do Ribeiro  Região Nordeste             0.192308
# 890   Lagoa Grande do Maranhão  Região Nordeste             4.036458
#
# [891 rows x 14 columns]

# %% [markdown]
# ### LIMIT

# %% [markdown]
# - Podemos usar o `LIMIT` para mostrar as primeiras `n` linhas

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      0   1       0               3   homem     22           1
# 1      1   2       1               1  mulher     38           1
# 2      2   3       1               3  mulher     26           0
# 3      3   4       1               1  mulher     35           1
# 4      4   5       0               3   homem     35           0
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF      CidadeResidencia  \
# 0            7250.0   517.857143   604.166667  MG  Morada Nova de Minas
# 1           71283.0  5091.642857  5940.250000  RN      Marcelino Vieira
# 2            7925.0   566.071429   660.416667  PR         Agudos do Sul
# 3             531.0    37.928571    44.250000  PR          Congonhinhas
# 4             805.0    57.500000    67.083333  BA               Morpará
#
#       RegiaodoPais  NumeroComprasOnline
# 0   Região Sudeste            54.924242
# 1  Região Nordeste           312.644737
# 2       Região Sul            50.801282
# 3       Região Sul             2.528571
# 4  Região Nordeste             3.833333

# %% [markdown]
# - Atenção, em bancos de dados SQLServer, o análogo ao `LIMIT` é o `TOP`
# - A sintaxe análoga seria:
#     - `SELECT TOP 5 * FROM AtrasoCartaoCredito`

# %% [markdown]
# ### WHERE

# %% [markdown]
# - Podemos filtar algumas observações com o comando `WHERE`

# %% [markdown]
# #### Igual `=`

# %%
df.shape
# Out:
# (891, 13)

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE Sexo = 'homem'
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico   Sexo  Idade  GrupoRisco  \
# 0      0   1       0               3  homem     22           1
# 1      4   5       0               3  homem     35           0
# 2      5   6       0               3  homem     22           0
# 3      6   7       0               1  homem     54           0
# 4      7   8       0               3  homem     20           3
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF      CidadeResidencia  \
# 0            7250.0   517.857143   604.166667  MG  Morada Nova de Minas
# 1             805.0    57.500000    67.083333  BA               Morpará
# 2           84583.0  6041.642857  7048.583333  AL             Carneiros
# 3           51862.0  3704.428571  4321.833333  PR              Figueira
# 4           21075.0  1505.357143  1756.250000  BA            Ouriçangas
#
#       RegiaodoPais  NumeroComprasOnline
# 0   Região Sudeste            54.924242
# 1  Região Nordeste             3.833333
# 2  Região Nordeste           640.780303
# 3       Região Sul           160.067901
# 4  Região Nordeste        175625.000000

# %% [markdown]
# #### Diferente `<>`

# %% [markdown]
# - `<>` significa "diferente", ou seja, selecionaremos todos `sexo` menos `homem`

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE Sexo <> 'homem'
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      1   2       1               1  mulher     38           1
# 1      2   3       1               3  mulher     26           0
# 2      3   4       1               1  mulher     35           1
# 3      8   9       1               3  mulher     27           0
# 4      9  10       1               2  mulher     14           1
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF  CidadeResidencia  \
# 0           71283.0  5091.642857  5940.250000  RN  Marcelino Vieira
# 1            7925.0   566.071429   660.416667  PR     Agudos do Sul
# 2             531.0    37.928571    44.250000  PR      Congonhinhas
# 3           11133.0   795.214286   927.750000  MG        Comercinho
# 4            3007.0   214.785714   250.583333  MG          Japonvar
#
#       RegiaodoPais  NumeroComprasOnline
# 0  Região Nordeste           312.644737
# 1       Região Sul            50.801282
# 2       Região Sul             2.528571
# 3   Região Sudeste            68.722222
# 4   Região Sudeste            35.797619

# %% [markdown]
# #### Maior `>`

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE GastoMedio > 1000
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      1   2       1               1  mulher     38           1
# 1      5   6       0               3   homem     22           0
# 2      6   7       0               1   homem     54           0
# 3      7   8       0               3   homem     20           3
# 4     13  14       0               3   homem     39           1
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF  CidadeResidencia  \
# 0           71283.0  5091.642857  5940.250000  RN  Marcelino Vieira
# 1           84583.0  6041.642857  7048.583333  AL         Carneiros
# 2           51862.0  3704.428571  4321.833333  PR          Figueira
# 3           21075.0  1505.357143  1756.250000  BA        Ouriçangas
# 4           31275.0  2233.928571  2606.250000  BA            Abaíra
#
#       RegiaodoPais  NumeroComprasOnline
# 0  Região Nordeste           312.644737
# 1  Região Nordeste           640.780303
# 2       Região Sul           160.067901
# 3  Região Nordeste        175625.000000
# 4  Região Nordeste           133.653846

# %% [markdown]
# #### Entre `BETWEEN`

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE GastoMedio BETWEEN 500 AND 1000
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      0   1       0               3   homem     22           1
# 1      2   3       1               3  mulher     26           0
# 2      8   9       1               3  mulher     27           0
# 3     19  20       1               3  mulher     45           0
# 4     26  27       0               3   homem     31           0
#
#    ValorCompraAnual    GastoMax  GastoMedio  UF      CidadeResidencia  \
# 0            7250.0  517.857143  604.166667  MG  Morada Nova de Minas
# 1            7925.0  566.071429  660.416667  PR         Agudos do Sul
# 2           11133.0  795.214286  927.750000  MG            Comercinho
# 3            7225.0  516.071429  602.083333  SE       Ilha Das Flores
# 4            7225.0  516.071429  602.083333  PB            Gado Bravo
#
#       RegiaodoPais  NumeroComprasOnline
# 0   Região Sudeste            54.924242
# 1       Região Sul            50.801282
# 2   Região Sudeste            68.722222
# 3  Região Nordeste            26.759259
# 4  Região Nordeste            38.844086

# %% [markdown]
# #### E `AND`

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE GastoMedio > 1000 AND Sexo = 'mulher'
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      1   2       1               1  mulher     38           1
# 1     14  15       0               3  mulher     14           0
# 2     22  23       1               3  mulher     15           0
# 3     24  25       0               3  mulher     80           3
# 4     25  26       1               3  mulher     30           1
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF  CidadeResidencia  \
# 0           71283.0  5091.642857  5940.250000  RN  Marcelino Vieira
# 1           78542.0  5610.142857  6545.166667  MG    Alto Jequitibá
# 2           80292.0  5735.142857  6691.000000  GO        Aragoiânia
# 3           21075.0  1505.357143  1756.250000  TO          Alvorada
# 4           31387.0  2241.928571  2615.583333  RR          Uiramutã
#
#           RegiaodoPais  NumeroComprasOnline
# 0      Região Nordeste           312.644737
# 1       Região Sudeste           935.023810
# 2  Região Centro-Oeste           892.133333
# 3         Região Norte           439.062500
# 4         Região Norte           174.372222

# %% [markdown]
# #### Ou `OR`

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE GastoMedio > 1000 OR CidadeResidencia = 'Agudos do Sul'
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      1   2       1               1  mulher     38           1
# 1      2   3       1               3  mulher     26           0
# 2      5   6       0               3   homem     22           0
# 3      6   7       0               1   homem     54           0
# 4      7   8       0               3   homem     20           3
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF  CidadeResidencia  \
# 0           71283.0  5091.642857  5940.250000  RN  Marcelino Vieira
# 1            7925.0   566.071429   660.416667  PR     Agudos do Sul
# 2           84583.0  6041.642857  7048.583333  AL         Carneiros
# 3           51862.0  3704.428571  4321.833333  PR          Figueira
# 4           21075.0  1505.357143  1756.250000  BA        Ouriçangas
#
#       RegiaodoPais  NumeroComprasOnline
# 0  Região Nordeste           312.644737
# 1       Região Sul            50.801282
# 2  Região Nordeste           640.780303
# 3       Região Sul           160.067901
# 4  Região Nordeste        175625.000000

# %% [markdown]
# #### Em `IN`

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE UF = 'BA' OR UF = 'PR'
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      2   3       1               3  mulher     26           0
# 1      3   4       1               1  mulher     35           1
# 2      4   5       0               3   homem     35           0
# 3      6   7       0               1   homem     54           0
# 4      7   8       0               3   homem     20           3
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF CidadeResidencia  \
# 0            7925.0   566.071429   660.416667  PR    Agudos do Sul
# 1             531.0    37.928571    44.250000  PR     Congonhinhas
# 2             805.0    57.500000    67.083333  BA          Morpará
# 3           51862.0  3704.428571  4321.833333  PR         Figueira
# 4           21075.0  1505.357143  1756.250000  BA       Ouriçangas
#
#       RegiaodoPais  NumeroComprasOnline
# 0       Região Sul            50.801282
# 1       Região Sul             2.528571
# 2  Região Nordeste             3.833333
# 3       Região Sul           160.067901
# 4  Região Nordeste        175625.000000

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE UF IN ('BA', 'PR')
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      2   3       1               3  mulher     26           0
# 1      3   4       1               1  mulher     35           1
# 2      4   5       0               3   homem     35           0
# 3      6   7       0               1   homem     54           0
# 4      7   8       0               3   homem     20           3
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF CidadeResidencia  \
# 0            7925.0   566.071429   660.416667  PR    Agudos do Sul
# 1             531.0    37.928571    44.250000  PR     Congonhinhas
# 2             805.0    57.500000    67.083333  BA          Morpará
# 3           51862.0  3704.428571  4321.833333  PR         Figueira
# 4           21075.0  1505.357143  1756.250000  BA       Ouriçangas
#
#       RegiaodoPais  NumeroComprasOnline
# 0       Região Sul            50.801282
# 1       Região Sul             2.528571
# 2  Região Nordeste             3.833333
# 3       Região Sul           160.067901
# 4  Região Nordeste        175625.000000

# %% [markdown]
# #### Não `NOT`

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE UF NOT IN ('BA', 'PR')
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      0   1       0               3   homem     22           1
# 1      1   2       1               1  mulher     38           1
# 2      5   6       0               3   homem     22           0
# 3      8   9       1               3  mulher     27           0
# 4      9  10       1               2  mulher     14           1
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF      CidadeResidencia  \
# 0            7250.0   517.857143   604.166667  MG  Morada Nova de Minas
# 1           71283.0  5091.642857  5940.250000  RN      Marcelino Vieira
# 2           84583.0  6041.642857  7048.583333  AL             Carneiros
# 3           11133.0   795.214286   927.750000  MG            Comercinho
# 4            3007.0   214.785714   250.583333  MG              Japonvar
#
#       RegiaodoPais  NumeroComprasOnline
# 0   Região Sudeste            54.924242
# 1  Região Nordeste           312.644737
# 2  Região Nordeste           640.780303
# 3   Região Sudeste            68.722222
# 4   Região Sudeste            35.797619

# %% [markdown]
# #### `LIKE`

# %%
query = '''
    SELECT *
    FROM AtrasoCartaoCredito
    WHERE UF LIKE 'A_'
    LIMIT 5
'''

pd.read_sql(query, engine)
# Out:
#    index  ID  Target  GrupoEconomico    Sexo  Idade  GrupoRisco  \
# 0      5   6       0               3   homem     22           0
# 1     37  38       0               3   homem     21           0
# 2     41  42       0               2  mulher     27           1
# 3     46  47       0               3   homem     34           1
# 4     47  48       1               3  mulher     15           0
#
#    ValorCompraAnual     GastoMax   GastoMedio  UF       CidadeResidencia  \
# 0           84583.0  6041.642857  7048.583333  AL              Carneiros
# 1             805.0    57.500000    67.083333  AL        Porto de Pedras
# 2              21.0     1.500000     1.750000  AM                 Silves
# 3             155.0    11.071429    12.916667  AC                 Bujari
# 4             775.0    55.357143    64.583333  AL  Olho D´água do Casado
#
#       RegiaodoPais  NumeroComprasOnline
# 0  Região Nordeste           640.780303
# 1  Região Nordeste             6.388889
# 2     Região Norte             0.129630
# 3     Região Norte             0.759804
# 4  Região Nordeste             8.611111

# %% [markdown]
# ### DISTINCT

# %% [markdown]
# - Podemos analisar os valores únicos de uma coluna

# %%
query = '''
    SELECT DISTINCT GrupoEconomico
    FROM AtrasoCartaoCredito
'''

pd.read_sql(query, engine)
# Out:
#    GrupoEconomico
# 0               3
# 1               1
# 2               2

# %%
query = '''
    SELECT DISTINCT UF
    FROM AtrasoCartaoCredito
'''

pd.read_sql(query, engine)
# Out:
#     UF
# 0   MG
# 1   RN
# 2   PR
# 3   BA
# 4   AL
# 5   RO
# 6   PB
# 7   SP
# 8   RS
# 9   SC
# 10  SE
# 11  GO
# 12  TO
# 13  RR
# 14  PI
# 15  AM
# 16  MA
# 17  AC
# 18  MS
# 19  MT
# 20  RJ
# 21  ES
# 22  PE
# 23  CE
# 24  AP
# 25  PA
